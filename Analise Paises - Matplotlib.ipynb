# %% [markdown]
# # IMPORTANDO PANDAS

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# ## Vídeo 1

# %% [markdown]
# https://www.youtube.com/watch?v=a9UrKTVEeZA
# Finalzinho do video para conclusão

# %%
x = [2, 4, 6]
y = [1, 5, 6]
z = [10, 5, 0]
plt.plot(x, y, 'o')
plt.plot(x, z)
plt.title('Gráfico')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend(["Este é o Y", "Este é o Z"])
plt.show()

# %% [markdown]
# # Comparação EUA e China

# %%
paises = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/PANDAS/DADOS/countries.csv')
paises.head(5)
# Out:
#        country  year  population
# 0  Afghanistan  1952     8425333
# 1  Afghanistan  1957     9240934
# 2  Afghanistan  1962    10267083
# 3  Afghanistan  1967    11537966
# 4  Afghanistan  1972    13079460

# %%
paises.country == 'Afghanistan'
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1699    False
# 1700    False
# 1701    False
# 1702    False
# 1703    False
# Name: country, Length: 1704, dtype: bool

# %%
us = paises[paises.country == 'United States']

# %%
us.head(2)
# Out:
#             country  year  population
# 1608  United States  1952   157553000
# 1609  United States  1957   171984000

# %%
ch = paises[paises.country == 'China']

# %%
ch.head(2)
# Out:
#     country  year  population
# 288   China  1952   556263527
# 289   China  1957   637408000

# %%
plt.plot(us.year, us.population / 10**6) #divisão em milhões para melhorar visualização
plt.plot(ch.year, ch.population / 10**6)
plt.legend(['EUA', 'China'])
plt.xlabel('Ano')
plt.ylabel('População')

plt.show()
