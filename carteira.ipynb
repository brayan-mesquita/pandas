# %%
import pandas as pd
import seaborn as sea
import yfinance as fin

# %%
lmt = fin.Ticker('LMT')

# %%
lmt.info
# Out:
# {'zip': '20817',
#  'sector': 'Industrials',
#  'fullTimeEmployees': 114000,
# ...
