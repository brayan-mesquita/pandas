# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/Users/brayan/Documents/projetos/pandas/dados/titanic.csv')

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
#tratar idades
df['Age'].fillna(28, inplace=True)

# %%
df['Age'].isnull().sum()
# Out:
# 0

# %%
h = np.histogram(df['Age'], bins= 8)
h
# Out:
# (array([ 64, 115, 407, 155,  86,  42,  17,   5]),
#  array([ 0.42  , 10.3675, 20.315 , 30.2625, 40.21  , 50.1575, 60.105 ,
#         70.0525, 80.    ]))

# %% [markdown]
# ## plt

# %%
plt.hist(df['Age'], bins=8)
plt.title('Hist. idade pessoas')
plt.ylabel('Pessoas')
plt.xlabel('Idade')
# Out:
# Text(0.5, 0, 'Idade')

# %%
plt.hist(df['Age'], bins=5)
plt.title('Hist. idade pessoas')
plt.ylabel('Pessoas')
plt.xlabel('Idade')
# Out:
# Text(0.5, 0, 'Idade')

# %% [markdown]
# ## seaborn

# %%
sns.histplot(df['Age'], kde=True, bins=25, color='red')
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(df['Age'], kde=False, bins=25, color='green')
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Count'>
