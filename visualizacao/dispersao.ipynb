# %% [markdown]
# <a href="https://colab.research.google.com/github/brayan-mesquita/pandas/blob/main/visualizacao/dispersao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # data frame sobre tamanhos de arvores

# %%
#df = pd.read_csv('/Users/brayan/Documents/cursos/FormacaoCD/13.Prática em Python/dados/trees.csv')
df = pd.read_csv('https://raw.githubusercontent.com/brayan-mesquita/pandas/main/dados/trees.csv')
df.columns = ['cir', 'alt', 'vol']
df.head()
# Out:
#     cir  alt   vol
# 0   8.3   70  10.3
# 1   8.6   65  10.3
# 2   8.8   63  10.2
# 3  10.5   72  16.4
# 4  10.7   81  18.8

# %% [markdown]
# ## plt

# %%
plt.scatter(df.alt, df.vol, color='green', facecolors = 'none', marker='o')
plt.title('relaçao entre altitude e circunferência')
plt.xlabel('Circunferência')
plt.ylabel('Altitude')
# Out:
# Text(0, 0.5, 'Altitude')

# %%
plt.scatter(df.vol, df.cir, color='blue', facecolors = 'none', marker='o')
plt.title('relaçao entre Volume e Circuferência')
plt.xlabel('Volume')
plt.ylabel('Circuferência')
# Out:
# Text(0, 0.5, 'Circuferência')

# %%
plt.plot(df.cir, df.vol)
plt.title('relaçao entre circunferencia e volume')
plt.xlabel('Circunferencia')
plt.ylabel('Volume')
# Out:
# Text(0, 0.5, 'Volume')

# %%
plt.hist(df.vol)
# Out:
# (array([ 5., 10.,  4.,  4.,  2.,  0.,  4.,  1.,  0.,  1.]),
#  array([10.2 , 16.88, 23.56, 30.24, 36.92, 43.6 , 50.28, 56.96, 63.64,
#         70.32, 77.  ]),
#  <a list of 10 Patch objects>)

# %%
plt.figure(1)
plt.subplot(2, 2, 1)
plt.scatter(df.cir, df.vol)
plt.subplot(2, 2, 2)
plt.scatter(df.cir, df.alt)
plt.subplot(2, 2, 3)
plt.scatter(df.alt, df.vol, marker='*')
plt.subplot(2, 2, 4)
plt.hist(df.vol)
# Out:
# (array([ 5., 10.,  4.,  4.,  2.,  0.,  4.,  1.,  0.,  1.]),
#  array([10.2 , 16.88, 23.56, 30.24, 36.92, 43.6 , 50.28, 56.96, 63.64,
#         70.32, 77.  ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## seaborn

# %%
#nao conseguio
