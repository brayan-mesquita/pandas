# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # data frame sobre tamanhos de arvores

# %%
df = pd.read_csv('/Users/brayan/Documents/cursos/FormacaoCD/13.Prática em Python/dados/trees.csv')
df.columns = ['cir', 'alt', 'vol']
df.head()
# Out:
#     cir  alt   vol
# 0   8.3   70  10.3
# 1   8.6   65  10.3
# 2   8.8   63  10.2
# 3  10.5   72  16.4
# 4  10.7   81  18.8

# %% [markdown]
# ## plt

# %%
plt.scatter(df.cir, df.alt, color='blue', facecolors = 'none', marker='o')
plt.title('relaçao entre circunferencia e volume')
plt.xlabel('Circunferência')
plt.ylabel('Altitude')
# Out:
# Text(0, 0.5, 'Altitude')

# %%
plt.plot(df.cir, df.vol)
plt.title('relaçao entre circunferencia e volume')
plt.xlabel('Circunferencia')
plt.ylabel('Volume')
# Out:
# Text(0, 0.5, 'Volume')

# %% [markdown]
# ## seaborn

# %%
#nao conseguio
